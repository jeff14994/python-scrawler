# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#利用-Python-存取-API" data-toc-modified-id="利用-Python-存取-API-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>利用 Python 存取 API</a></span><ul class="toc-item"><li><span><a href="#作業目標" data-toc-modified-id="作業目標-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>作業目標</a></span><ul class="toc-item"><li><span><a href="#比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異" data-toc-modified-id="比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異</a></span></li><li><span><a href="#r.text-是-raw-data-(如下圖)" data-toc-modified-id="r.text-是-raw-data-(如下圖)-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>r.text 是 raw data (如下圖)</a></span></li><li><span><a href="#json.loads(r.text)-是格式化後的-data(如下圖)" data-toc-modified-id="json.loads(r.text)-是格式化後的-data(如下圖)-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>json.loads(r.text) 是格式化後的 data(如下圖)</a></span></li><li><span><a href="#自行尋找一個合適的-API-接口做練習，並且查看其回傳內容" data-toc-modified-id="自行尋找一個合適的-API-接口做練習，並且查看其回傳內容-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>自行尋找一個合適的 API 接口做練習，並且查看其回傳內容</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %% [markdown]
# ### r.text 是 raw data (如下圖)
# ![](https://i.imgur.com/WkiLWDS.jpg)
# ### json.loads(r.text) 是格式化後的 data(如下圖)
# ![](https://i.imgur.com/XKPxg6s.png)

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 抓 cat-facts 的 API 資料 (https://cat-fact.herokuapp.com/facts)

# %%
import requests
# Resources: https://requests.readthedocs.io/en/master/api/#requests.Response
response = requests.get("https://cat-fact.herokuapp.com/facts")
response.text
# Out:
# '{"all":[{"_id":"58e00a1a0aac31001185ed18","text":"Cats and humans have nearly identical sections of the brain that control emotion.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":15,"userUpvoted":null},{"_id":"5b0c5e3e7ab3c50014df65fe","text":"People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":9,"userUpvoted":null},{"_id":"58e00a000aac31001185ed15","text":"Female cats are typically right-pawed while male cats are typically left-pawed.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":8,"userUpvoted":null},{"_id":"5b1b4055841d9700146158d3","text":"Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.","type":"cat","us
# ...

# %%
import json
json.loads(data.text)
# Out:
# {'all': [{'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 15,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '58e00a000aac31001185ed15',
#    'text': 'Female cats are typically right-pawed while male cats are typically left-pawed.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
# ...

# %% [markdown]
# ### 抓政府即時水位資料(http://odata.wra.gov.tw/v4/RealtimeWaterLevel)

# %%
import requests
response = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel")
response.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 0,\n"value": []}'

# %%
import json
json.loads(response.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 0,
#  'value': []}
