# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#反爬：登入授權模擬" data-toc-modified-id="反爬：登入授權模擬-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>反爬：登入授權模擬</a></span><ul class="toc-item"><li><span><a href="#未授權前存取" data-toc-modified-id="未授權前存取-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>未授權前存取</a></span></li><li><span><a href="#模仿授權機制" data-toc-modified-id="模仿授權機制-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>模仿授權機制</a></span><ul class="toc-item"><li><span><a href="#方法一：先送登入，再送請求" data-toc-modified-id="方法一：先送登入，再送請求-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>方法一：先送登入，再送請求</a></span></li><li><span><a href="#方法二：在請求中帶入-cookie" data-toc-modified-id="方法二：在請求中帶入-cookie-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>方法二：在請求中帶入 cookie</a></span></li></ul></li><li><span><a href="#作業目標" data-toc-modified-id="作業目標-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>作業目標</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# /Users/hungyuchuan/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/hungyuchuan/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /Users/hungyuchuan/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/hungyuchuan/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/hungyuchuan/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 3
#
# [問卦] 會不會有店家靠萊豬魚木混珠？
#
#
# zxzx485612
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zxzx485612 的文章
#
#
#  1/05
#
#
#
#
# 1
#
# Re: [問卦] 環保少女怎麼變那麼肥？
#
#
# Qorqios
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Qorqios 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 有一種冰叫洞洞果？
#
#
# sharkloveeat
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sharkloveeat 的文章
#
#
#  1/05
#
#
#
#
# 3
#
# Re: [新聞] 「天網」涉侵犯人權 國家人權委員會：疫
#
#
# DustToDust
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 DustToDust 的文章
#
#
#  1/05
#
#
#
#
# 9
#
# [問卦] 平偉去鴨肉店會發生什麼事？
#
#
# hushiang
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hushiang 的文章
#
#
#  1/05
#
#
#
#
#
#
# Re: [新聞] 「天網」涉侵犯人權 國家人權委員會：疫
#
#
# A6
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 A6 的文章
#
#
#  1/05
#
#
#
#
# 1
#
# [問卦] =.= 花椒是不是上帝的調味料阿？！
#
#
# xzcb2008
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xzcb2008 的文章
#
#
#  1/05
#
#
#
#
# 1
#
# [問卦] 手機app有需要一直更新嗎？
#
#
# Secret69
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Secret69 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 俄羅斯砲兵很強嗎？
#
#
# FireHawk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FireHawk 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 千千去鴨肉店被霸凌會怎麼辦
#
#
# Audrey23
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Audrey23 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 大安中正區生日蛋糕哪裡買
#
#
# GraceMa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 GraceMa 的文章
#
#
#  1/05
#
#
#
#
# 2
#
# [問卦] 菜々緒會喜歡比她矮的人嗎？
#
#
# NTULioner
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 NTULioner 的文章
#
#
#  1/05
#
#
#
#
# 1
#
# [問卦] 鴨子毛沒有長齊可以來嗎？
#
#
# WeGoStyle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 WeGoStyle 的文章
#
#
#  1/05
#
#
#
#
#
#
# Re: [問卦] 傑森史塔森去鴨肉店 被霸凌該怎麼辦??
#
#
# s0930194
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 s0930194 的文章
#
#
#  1/05
#
#
#
#
#
#
# [新聞] 武漢肺炎增2例境外移入 累計817例  最後
#
#
# XDDDDDDDDDD
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 XDDDDDDDDDD 的文章
#
#
#  1/05
#
#
#
#
#
#
# [爆卦] 台股萬五啦
#
#
# Dogman7788
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Dogman7788 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 這樣會很魯嗎？
#
#
# cuba391156
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cuba391156 的文章
#
#
#  1/05
#
#
#
#
#
#
# [問卦] 有沒有萬五棒康的八卦
#
#
# cutbear123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cutbear123 的文章
#
#
#  1/05
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.11.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
# 11/21
# !
#
#
#
# 1
#
# [公告] 一月份置底閒聊區
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
#  1/01
#
#
#
#
# 12
#
# [協尋] 2021/1/1 行車紀錄器 新莊IKEA路口
#
#
# owem777
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 owem777 的文章
#
#
#  1/03
#
#
#
#
# 2
#
# [協尋] 2021/1/4 行車紀錄器 基隆路三段
#
#
# owen801215
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 owen801215 的文章
#
#
#  1/04
# M
#
#
#
# 爆
#
# [公告] 跟鄉民一起織八卦安全網 案2 (發錢)
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
#  1/04
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# Re: [新聞]「台灣野人」恆春半島吃不停 林管處盼吸收
#
#
# hltinokuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hltinokuo 的文章
#
#
#  7/29
#
#
#
#
# 3
#
# [問卦] 香港運輸物資居然用大隊接力！
#
#
# charco
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 charco 的文章
#
#
#  7/29
#
#
#
#
# 7
#
# [問卦] 有人會直接吃鮪魚罐頭嗎
#
#
# Antihuman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Antihuman 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 海底撈點這樣算摳嗎？
#
#
# danmitsu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 danmitsu 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 為什麼台灣找不到混血黑人球員??
#
#
# kerkerson
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kerkerson 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] 不會念書的人有女友嗎？
#
#
# Francise
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Francise 的文章
#
#
#  7/29
#
#
#
#
#
#
# [新聞] IZ*ONE熱潮狂掃《TGC 富山 2019》 八千人
#
#
# ATCTaiwan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ATCTaiwan 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# Re: [新聞] 回應韓國瑜 蔡英文：守護中華民國我說到
#
#
# cowardlyman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cowardlyman 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# [問卦] 農藥店真的很賺嗎？
#
#
# brucielu95
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucielu95 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] STU瀧野由美子終究只是個第三者嗎?
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  7/29
#
#
#
#
#
#
# Re: [問卦] 買私菸的官員會不會變成世紀罪人？
#
#
# fuxdk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fuxdk 的文章
#
#
#  7/29
#
#
#
#
# 6
#
# Re: [問卦] 俄羅斯小蘿莉在跳什麼舞？
#
#
# violinlife
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 violinlife 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 洗完雞雞容易激起性慾嗎
#
#
# dinex
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dinex 的文章
#
#
#  7/29
#
#
#
#
# 4
#
# [問卦] 為什麼教科書都要寫「偽」滿洲國？
#
#
# leopika
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leopika 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 假日時光倒流，想回去什麼時候
#
#
# blackzero1
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 blackzero1 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 台鐵補票事件是不是顯露部分台灣人醜陋?
#
#
# MizunaRei
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 MizunaRei 的文章
#
#
#  7/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.07.21)
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/21
# !
#
#
#
# 63
#
# [問卦]懇求7/19大溪往三峽路段死亡車禍行車紀錄
#
#
# nekosandy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nekosandy 的文章
#
#
#  7/21
# M
#
#
#
# 19
#
# [公告] 版規4-16修正草案
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  7/23
# M
#
#
#
# 87
#
# [尋人]尋人啟事 懇請幫忙
#
#
# skysea0940
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skysea0940 的文章
#
#
#  7/26
#
#
#
#
# 39
#
# [公告] 七月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/wei/.virtualenvs/py3/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
