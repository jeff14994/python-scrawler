# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Wikipedia爬蟲練習" data-toc-modified-id="Wikipedia爬蟲練習-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Wikipedia爬蟲練習</a></span><ul class="toc-item"><li><span><a href="#範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。" data-toc-modified-id="範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。</a></span><ul class="toc-item"><li><span><a href="#先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL" data-toc-modified-id="先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL</a></span></li><li><span><a href="#範例1：送出關鍵字請求後，爬取該關鍵字的文章內容" data-toc-modified-id="範例1：送出關鍵字請求後，爬取該關鍵字的文章內容-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>範例1：送出關鍵字請求後，爬取該關鍵字的文章內容</a></span></li><li><span><a href="#範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。" data-toc-modified-id="範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。</a></span></li></ul></li><li><span><a href="#作業：接下來定義一個爬蟲函數，這個函數的主要工作為：" data-toc-modified-id="作業：接下來定義一個爬蟲函數，這個函數的主要工作為：-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>作業：接下來定義一個爬蟲函數，這個函數的主要工作為：</a></span><ul class="toc-item"><li><span><a href="#(1)-爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)" data-toc-modified-id="(1)-爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>(1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)</a></span></li><li><span><a href="#(2)-萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字" data-toc-modified-id="(2)-萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>(2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字</a></span></li><li><span><a href="#(3)-把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。" data-toc-modified-id="(3)-把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>(3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。</a></span></li><li><span><a href="#執行前個步驟定義好的爬蟲主程式" data-toc-modified-id="執行前個步驟定義好的爬蟲主程式-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>執行前個步驟定義好的爬蟲主程式</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup
import os

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "網路爬蟲"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
# utf8_url = str(input_keyword.encode('UTF-8')).upper() # str() vs repr()
# print(utf8_url)
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print(utf8_url)
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# B'%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2'
# 網路爬蟲: %E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2
# /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
# print(content)
#
# 解析回傳資料，並萃取文章內容(只取 tag 裡面的內容)
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-684f428410da> in <module>
#      22 html = BeautifulSoup(resp.text, "lxml")
#      23 content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
# ---> 24 print(content.get_text())
#      25 #
#      26 # 解析回傳資料，並萃取文章內容(只取 tag 裡面的內容)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# ...

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    # (?!;) -> negative lookahead 後面不可為 ;
    # \S 表示匹配非空白字元
    # *$ 結尾可以是任意的字元
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    # 若 a_tag 裡有內容，取該網址
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [robots.txt] /wiki/Robots.txt
# 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# 外部連結: [HTML] /wiki/HTML
# 外部連結: [網路抓取] /wiki/%E7%BD%91%E7%BB%9C%E6%8A%93%E5%8F%96
# 外部連結: [資料驅動編程] /wiki/%E6%95%B0%E6%8D%AE%E9%A9%B1%E5%8A%A8%E7%BC%96%E7%A8%8B
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
#  WikiArticle 第三個參數表示 recursive 從第幾從開始
def WikiArticle(key_word_link, key_word, recursive):
    # Recursive function 終止條件
    if (recursive <= max_recursive_depth):
        # 印出現在網也層數
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 發起請求
        cont = request_html(key_word_link)
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        # 建立資料夾並下載
        download_content(key_word, cont)    
        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        # 獲取該關鍵字網頁出現的其他外部連結      
        external_link_dict = get_ext_link(content)
                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        # 判斷是否有外部連結
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            #  取出網址與關線字
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# 發起請求
def request_html(key_word_link):
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        # 將該關鍵字內容彙整起來 
        cont = ""
        for paragraph in content:
            cont += paragraph.get_text()
            # print(paragraph.get_text())
        # print(cont)
        return cont
    
# 建立資料夾並下載
def download_content(key_word, cont):
    # 判斷資料夾是否存在，若否，建立一個新的
    outpur_dir = "./WikiArticle/"
    if not os.path.exists(outpur_dir):
        os.makedirs(outpur_dir)
    # 將檔案寫入
    # file name: key_word
    with open(outpur_dir + key_word + ".txt", "w") as f:
        f.write(cont)
        print("Downloading %s..."%key_word)
        print("\n")
        
# 獲取該關鍵字網頁出現的其他外部連結      
def get_ext_link(content):
    external_link_dict = dict({})
    for ext_link in content:
        # (?!;) -> negative lookahead 後面不可為 ;
        # \S 表示匹配非空白字元
        # *$ 結尾可以是任意的字元
        a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
        # 若 a_tag 裡有內容，取該網址
        if len(a_tag) > 0:
            for link_string in a_tag:
                a_link = link_string["href"]       # 外部連結的網址
                a_keyword = link_string.get_text()  # 外部連結的中文名稱
                # 將外部連結用 key - value 的方式儲存成 dict (key 是網址， value 是關鍵字)
                external_link_dict[link_string["href"]] = link_string.get_text()
                print("外部連結: [%s] %s" % (a_keyword, a_link))
    return external_link_dict

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 2

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2 (網路爬蟲)
# ...
#
#
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [robots.txt] /wiki/Robots.txt
# 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# 外部連結: [HTML] /wiki/HTML
# 外部連結: [網路抓取] /wiki/%E7%BD%91%E7%BB%9C%E6%8A%93%E5%8F%96
# 外部連結: [資料驅動編程] /wiki/%E6%95%B0%E6%8D%AE%E9%A9%B1%E5%8A%A8%E7%BC%96%E7%A8%8B
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A
# 遞迴層[1] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# ...
#
#
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# ...

# %% [markdown]
# ### Result

# %% [markdown]
# ![](https://i.imgur.com/p4MulLT.jpg)
