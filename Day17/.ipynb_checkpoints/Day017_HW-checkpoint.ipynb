# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#HTTP-動態網頁架構說明" data-toc-modified-id="HTTP-動態網頁架構說明-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>HTTP 動態網頁架構說明</a></span><ul class="toc-item"><li><span><a href="#作業目標" data-toc-modified-id="作業目標-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>作業目標</a></span><ul class="toc-item"><li><span><a href="#1.-動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？" data-toc-modified-id="1.-動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？</a></span></li><li><span><a href="#2.-還記得我們在-ETTODAY-靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來，-試著回答看看原因是什麼？及該如何檢查？" data-toc-modified-id="2.-還記得我們在-ETTODAY-靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來，-試著回答看看原因是什麼？及該如何檢查？-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？</a></span></li><li><span><a href="#問題點：橘色框起來往下的資料都沒有撈回來" data-toc-modified-id="問題點：橘色框起來往下的資料都沒有撈回來-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>問題點：橘色框起來往下的資料都沒有撈回來</a></span></li><li><span><a href="#試著回答看看原因是什麼？及該如何檢查？" data-toc-modified-id="試著回答看看原因是什麼？及該如何檢查？-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>試著回答看看原因是什麼？及該如何檢查？</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # HTTP 動態網頁架構說明
#
#
# * 了解動態網頁的資料爬蟲策略
# * 知道非同步網頁載入機制（Ajax）
# * 學習兩種對應動態網頁爬蟲的的策略

# %% [markdown]
# ## 作業目標
#
# 回答以下問題：
#
# 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？
# 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# ### 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？

# %% [markdown]
# - 靜態網頁與動態網頁的差異
#     - 靜態網頁: 回傳整個頁面
#     - 動態網頁: 如果使用 AJAX 非同步的技術的話，可以只回傳資料
# - 靜態網頁的缺點是
#     - 若 Server 的處裡時間長，則 Client 端需要長時間等待，因此後續的程式需要等到 Server 回傳資料後才能執行

# %% [markdown]
# ### 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %%
import requests
from bs4 import BeautifulSoup
# get url soup(Parsed)
url = "https://www.ettoday.net/news/news-list.htm"
def get_soup(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

soup = get_soup(url)
total = 0
# Find specific target
for data in soup.find(class_="part_list_2").find_all("h3"):
    date = data.find(class_="date").text
    content = data.find_all('a')[-1].text
    print(date, content)
    total += 1
print("共100則新聞: %d"%total)
# Out:
# 2020/12/20 09:58 市場最強捕手瑞爾穆托　國民想衝了！就看老闆意思
# 2020/12/20 09:56 南迴鐵路電氣化今全線通車了！關鍵「鐵路快捷化」終於等到
# 2020/12/20 09:52 厄文賽前燒草祈福　杜蘭特力挺：「或許他打電動前也會燒」
# 2020/12/20 09:52 高鐵今晚加開1列北返列車　1910左營出發各站皆停靠
# 2020/12/20 09:52 紐約影評人協會完整得獎名單出爐！　「黑豹」查德威克奪最佳男配
# 2020/12/20 09:47 巫師小將攻擊「笑臉」葛瑞芬＋裁判　新季首張罰單降臨
# 2020/12/20 09:47 耶誕老人苦哈哈　熱線瑪麗亞凱莉送禮物！聖誕節應景追劇3連發
# 2020/12/20 09:45 陸出手審查外商投資安全　台灣投資者「影響國安」也列入
# 2020/12/20 09:36 連勝文挺盧秀燕反萊豬　嗆民進黨買辦「哪門子愛台灣顧主權」
# 2020/12/20 09:36 全球力推電動車讓TOYOTA社長怒了！豐田章男：這根本是過度炒作
# 2020/12/20 09:30 感冒只能開3天藥？藥師：有「100種疾病」一次可拿1個月　處方箋曝
# 2020/12/20 09:30 一票餵到底！宜蘭傻萌系親子農場　抱可愛小豬豬、跟大水牛散步
# 2020/12/20 09:27 影／機車考照上駕訓班補助1300「明年元旦起續辦11個月」  交通部證實
# 2020/12/20 09:27 13歲哈士奇爺爺「遊覽車初體驗」展暖笑　爸解釋命名由來藏洋蔥
# 2020/12/20 09:22 勇士「嘴綠」恐傷缺開幕戰　格林對決KD戲碼再等等
# 2020/12/20 09:22 台中「猛獸級跑車」凌晨過彎自撞分隔島！前保桿破裂、車牌慘噴飛
# 2020/12/20 09:20 保證年底脫單！4招養成「戀愛體質」融入陌生場合、保持獨立超加分
# 2020/12/20 09:12 王牌薛茲爾7年合約快到期　國民至今還沒談續約
# 2020/12/20 09:11 刷完牙先別急著漱口？醫證實「沒有錯」…揭1關鍵強化琺瑯質
# 2020/12/20 09:10 考照魔王題！「汽機車到路口，誰該禮讓誰」　超過一半答錯
# ...

# %% [markdown]
# ### 問題點：橘色框起來往下的資料都沒有撈回來

# %% [markdown]
# ![](https://i.imgur.com/Si78BX5.png)

# %% [markdown]
# ### 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# - 原因：
#     - 可能是爬蟲有爬的上限（Requests 這個模組的問題）
#     - 可能 Server 有擋
# - 檢查方式：
#     - 程式設計者回去需要交叉檢查（程式的 Output 與實際網頁的 Output  的差異）
