# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#動態網頁爬蟲---API-Request" data-toc-modified-id="動態網頁爬蟲---API-Request-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>動態網頁爬蟲 - API Request</a></span><ul class="toc-item"><li><span><a href="#觀察-API-請求資訊" data-toc-modified-id="觀察-API-請求資訊-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>觀察 API 請求資訊</a></span></li><li><span><a href="#作業目標" data-toc-modified-id="作業目標-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>作業目標</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/qBmCUxR.jpg)

# %% [markdown]
# ![](https://imgur.com/Xi5kYFX.jpg)

# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-12-22T10:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 12585.2099953657,
#     'CapacityRate': 63.75324837448747,
#     'Status': 5,
#     'Basin_Rain': 5.4,
#     'EffectiveCapacity': 19740.5,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-12-22T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 929.0,
#     'CapacityRate': 92.71457085828342,
#     'Status': 5,
#     'Basin_Rain': 33.5,
#     'EffectiveCapacity': 1002.0,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-12-22T09:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 31552.68,
#     'CapacityRate': 94.04533464478921,
#     'Status': 5,
# ...

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。
